# %%
import pandas as pd

# %%
sorted_df=pd.read_csv('output/sorted_df.csv')
sorted_df=sorted_df.iloc[:, 1:]
sorted_df
# Out:
#     labels                             companies
# 0        0           ('Northrop Grumman', 'NOC')
# 1        0      ('Verizon Communications', 'VZ')
# 2        0                ('Amgen Inc.', 'AMGN')
# 3        0                    ('Visa Inc.', 'V')
# 4        0                        ('IBM', 'IBM')
# 5        0                ('Masco Corp.', 'MAS')
# 6        1             ('NextEra Energy', 'NEE')
# 7        1    ('Applied Materials Inc.', 'AMAT')
# 8        1                    ('Amazon', 'AMZN')
# 9        1                ('Nucor Corp.', 'NUE')
# 10       1               ('Target Corp.', 'TGT')
# 11       1               ('Lennar Corp.', 'LEN')
# 12       2            ('Lockheed Martin', 'LMT')
# 13       2            ('Whirlpool Corp.', 'WHR')
# 14       2                     ('Apple', 'AAPL')
# 15       2              ('General Motors', 'GM')
# 16       2          ('AmerisourceBergen', 'ABC')
# 17       2             ('HCA Healthcare', 'HCA')
# 18       3                 ('Deere & Co.', 'DE')
# 19       3      ('United Parcel Service', 'UPS')
# 20       3                      ('Boeing', 'BA')
# 21       3                  ('MasterCard', 'MA')
# 22       3            ('General Electric', 'GE')
# 23       4    ('UnitedHealth Group Inc.', 'UNH')
# 24       4          ('Texas Instruments', 'TXN')
# 25       4           ('Vulcan Materials', 'VMC')
# 26       4  ('Pioneer Natural Resources', 'PXD')
# 27       4                 ('Microsoft', 'MSFT')
# 28       4           ('Lincoln National', 'LNC')
# 29       4                ('Adobe Inc.', 'ADBE')
# 30       4           ('American Express', 'AXP')
# 31       5                    ('Celanese', 'CE')
# 32       5                     ('Intel', 'INTC')
# 33       6          ('Lilly (Eli) & Co.', 'LLY')
# 34       6              ('Netflix Inc.', 'NFLX')
# 35       6                  ('Kroger Co.', 'KR')
# 36       6  ('Alphabet Inc. (Class A)', 'GOOGL')
# 37       7                   ('Walgreen', 'WBA')
# 38       7          ('Progressive Corp.', 'PGR')
# 39       7                   ('Prologis', 'PLD')
# 40       7              ('Chevron Corp.', 'CVX')
# 41       7         ('TJX Companies Inc.', 'TJX')
# 42       8                 ('3M Company', 'MMM')
# 43       8          ('Johnson & Johnson', 'JNJ')
# 44       8       ('JPMorgan Chase & Co.', 'JPM')
# 45       8                  ('McDonalds', 'MCD')
# 46       9                      ('Pepsi', 'PEP')
# 47       9                   ('Coca Cola', 'KO')
# 48       9              ('Medtronic plc', 'MDT')
# 49       9       ('Waste Management Inc.', 'WM')

# %%
sorted_df[['company_name', 'company_symbol']]=sorted_df['companies'].str.replace('(', '').str.replace(')', '').str.replace("'", '').str.split(', ', expand=True)#[1]
# sorted_df
sorted_df=sorted_df.replace({'Alphabet Inc. Class A': 'Alphabet Inc. (Class A)', 
                   'Lilly Eli & Co.': 'Lilly (Eli) & Co.'})
sorted_df
# Out:
# /Users/kevinlee/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
#     labels                             companies               company_name  \
# 0        0           ('Northrop Grumman', 'NOC')           Northrop Grumman
# 1        0      ('Verizon Communications', 'VZ')     Verizon Communications
# 2        0                ('Amgen Inc.', 'AMGN')                 Amgen Inc.
# 3        0                    ('Visa Inc.', 'V')                  Visa Inc.
# 4        0                        ('IBM', 'IBM')                        IBM
# 5        0                ('Masco Corp.', 'MAS')                Masco Corp.
# 6        1             ('NextEra Energy', 'NEE')             NextEra Energy
# 7        1    ('Applied Materials Inc.', 'AMAT')     Applied Materials Inc.
# 8        1                    ('Amazon', 'AMZN')                     Amazon
# 9        1                ('Nucor Corp.', 'NUE')                Nucor Corp.
# 10       1               ('Target Corp.', 'TGT')               Target Corp.
# 11       1               ('Lennar Corp.', 'LEN')               Lennar Corp.
# 12       2            ('Lockheed Martin', 'LMT')            Lockheed Martin
# 13       2            ('Whirlpool Corp.', 'WHR')            Whirlpool Corp.
# 14       2                     ('Apple', 'AAPL')                      Apple
# 15       2              ('General Motors', 'GM')             General Motors
# 16       2          ('AmerisourceBergen', 'ABC')          AmerisourceBergen
# 17       2             ('HCA Healthcare', 'HCA')             HCA Healthcare
# 18       3                 ('Deere & Co.', 'DE')                Deere & Co.
# 19       3      ('United Parcel Service', 'UPS')      United Parcel Service
# 20       3                      ('Boeing', 'BA')                     Boeing
# 21       3                  ('MasterCard', 'MA')                 MasterCard
# 22       3            ('General Electric', 'GE')           General Electric
# 23       4    ('UnitedHealth Group Inc.', 'UNH')    UnitedHealth Group Inc.
# 24       4          ('Texas Instruments', 'TXN')          Texas Instruments
# 25       4           ('Vulcan Materials', 'VMC')           Vulcan Materials
# 26       4  ('Pioneer Natural Resources', 'PXD')  Pioneer Natural Resources
# 27       4                 ('Microsoft', 'MSFT')                  Microsoft
# 28       4           ('Lincoln National', 'LNC')           Lincoln National
# 29       4                ('Adobe Inc.', 'ADBE')                 Adobe Inc.
# 30       4           ('American Express', 'AXP')           American Express
# 31       5                    ('Celanese', 'CE')                   Celanese
# 32       5                     ('Intel', 'INTC')                      Intel
# 33       6          ('Lilly (Eli) & Co.', 'LLY')          Lilly (Eli) & Co.
# 34       6              ('Netflix Inc.', 'NFLX')               Netflix Inc.
# 35       6                  ('Kroger Co.', 'KR')                 Kroger Co.
# 36       6  ('Alphabet Inc. (Class A)', 'GOOGL')    Alphabet Inc. (Class A)
# 37       7                   ('Walgreen', 'WBA')                   Walgreen
# 38       7          ('Progressive Corp.', 'PGR')          Progressive Corp.
# 39       7                   ('Prologis', 'PLD')                   Prologis
# 40       7              ('Chevron Corp.', 'CVX')              Chevron Corp.
# 41       7         ('TJX Companies Inc.', 'TJX')         TJX Companies Inc.
# 42       8                 ('3M Company', 'MMM')                 3M Company
# 43       8          ('Johnson & Johnson', 'JNJ')          Johnson & Johnson
# 44       8       ('JPMorgan Chase & Co.', 'JPM')       JPMorgan Chase & Co.
# 45       8                  ('McDonalds', 'MCD')                  McDonalds
# 46       9                      ('Pepsi', 'PEP')                      Pepsi
# 47       9                   ('Coca Cola', 'KO')                  Coca Cola
# 48       9              ('Medtronic plc', 'MDT')              Medtronic plc
# 49       9       ('Waste Management Inc.', 'WM')      Waste Management Inc.
#
#    company_symbol
# 0             NOC
# 1              VZ
# 2            AMGN
# 3               V
# 4             IBM
# 5             MAS
# 6             NEE
# 7            AMAT
# 8            AMZN
# 9             NUE
# 10            TGT
# 11            LEN
# 12            LMT
# 13            WHR
# 14           AAPL
# 15             GM
# 16            ABC
# 17            HCA
# 18             DE
# 19            UPS
# 20             BA
# 21             MA
# 22             GE
# 23            UNH
# 24            TXN
# 25            VMC
# 26            PXD
# 27           MSFT
# 28            LNC
# 29           ADBE
# 30            AXP
# 31             CE
# 32           INTC
# 33            LLY
# 34           NFLX
# 35             KR
# 36          GOOGL
# 37            WBA
# 38            PGR
# 39            PLD
# 40            CVX
# 41            TJX
# 42            MMM
# 43            JNJ
# 44            JPM
# 45            MCD
# 46            PEP
# 47             KO
# 48            MDT
# 49             WM

# %%
test=pd.to_datetime(['2021-04-16 00:00:00+00:00'])
# test.strftime('%Y-%m-%d')
test.tz_convert(None)
# Out:
# DatetimeIndex(['2021-04-16'], dtype='datetime64[ns]', freq=None)

# %%
movement_df=pd.read_csv('output/movements_df.csv')
# movement_df
# columns=movement_df.iloc[0, :]
# columns

# movement_df=movement_df.iloc[1:]
# columns=movement_df.iloc[:, 0]
# movement_df=movement_df.transpose()
# movement_df.columns=columns
# movement_df=movement_df.iloc[1:]
columns=list(movement_df.columns)
new_columns=[]
for each_column in columns: 
#     print(each_column)
    new_columns.append(each_column.replace('00:00:00+00:00', ''))
movement_df.columns=new_columns
# movement_df.head()

# %%
combined_df['labels'].value_counts()
# Out:
# 4    8
# 0    6
# 1    6
# 2    6
# 3    5
# 7    5
# 6    4
# 8    4
# 9    4
# 5    2
# Name: labels, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
combined_df=pd.merge(movement_df, sorted_df, left_on='Unnamed: 0', right_on='company_name', how='outer')
combined_df=combined_df.drop(columns=['companies', 'company_name', 'company_symbol'])
combined_df
for each_cluster in range(0, 10): 
    graph_df=combined_df[combined_df['labels']==each_cluster].drop(columns=['labels'])
    graph_df=graph_df.transpose()#.plot()
    columns=graph_df.iloc[0]
    graph_df.columns=columns
    graph_df.iloc[1:].plot(rot=90, legend=False)
    plt.legend(bbox_to_anchor=(1, 1))
    plt.savefig(f'static/charts/cluster_{each_cluster}')

# %%
test_df=graph_df.transpose()
test_df.plot()
