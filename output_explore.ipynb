# %%
import pandas as pd

# %%
sorted_df=pd.read_csv('output/sorted_df.csv')
sorted_df=sorted_df.iloc[:, 1:]
sorted_df
# Out:
#     labels                             companies               company_name  \
# 0        0           ('Lincoln National', 'LNC')           Lincoln National
# 1        0    ('Applied Materials Inc.', 'AMAT')     Applied Materials Inc.
# 2        0             ('NextEra Energy', 'NEE')             NextEra Energy
# 3        0                    ('Amazon', 'AMZN')                     Amazon
# 4        0           ('American Express', 'AXP')           American Express
# 5        0               ('Target Corp.', 'TGT')               Target Corp.
# 6        0                ('Nucor Corp.', 'NUE')                Nucor Corp.
# 7        0               ('Lennar Corp.', 'LEN')               Lennar Corp.
# 8        1                  ('Kroger Co.', 'KR')                 Kroger Co.
# 9        1                ('Masco Corp.', 'MAS')                Masco Corp.
# 10       1                        ('IBM', 'IBM')                        IBM
# 11       1              ('Netflix Inc.', 'NFLX')               Netflix Inc.
# 12       1  ('Alphabet Inc. (Class A)', 'GOOGL')    Alphabet Inc. (Class A)
# 13       1          ('Lilly (Eli) & Co.', 'LLY')          Lilly (Eli) & Co.
# 14       1                ('Amgen Inc.', 'AMGN')                 Amgen Inc.
# 15       1                    ('Visa Inc.', 'V')                  Visa Inc.
# 16       1      ('Verizon Communications', 'VZ')     Verizon Communications
# 17       1           ('Northrop Grumman', 'NOC')           Northrop Grumman
# 18       2                 ('Deere & Co.', 'DE')                Deere & Co.
# 19       2                      ('Boeing', 'BA')                     Boeing
# 20       2                  ('MasterCard', 'MA')                 MasterCard
# 21       2            ('General Electric', 'GE')           General Electric
# 22       3            ('Whirlpool Corp.', 'WHR')            Whirlpool Corp.
# 23       3                     ('Apple', 'AAPL')                      Apple
# 24       3          ('AmerisourceBergen', 'ABC')          AmerisourceBergen
# 25       3            ('Lockheed Martin', 'LMT')            Lockheed Martin
# 26       3             ('HCA Healthcare', 'HCA')             HCA Healthcare
# 27       3              ('General Motors', 'GM')             General Motors
# 28       4          ('Progressive Corp.', 'PGR')          Progressive Corp.
# 29       4                   ('Walgreen', 'WBA')                   Walgreen
# 30       4         ('TJX Companies Inc.', 'TJX')         TJX Companies Inc.
# 31       4                   ('Prologis', 'PLD')                   Prologis
# 32       4              ('Chevron Corp.', 'CVX')              Chevron Corp.
# 33       5                    ('Celanese', 'CE')                   Celanese
# 34       5                     ('Intel', 'INTC')                      Intel
# 35       6                   ('Coca Cola', 'KO')                  Coca Cola
# 36       6              ('Medtronic plc', 'MDT')              Medtronic plc
# 37       6                      ('Pepsi', 'PEP')                      Pepsi
# 38       6       ('Waste Management Inc.', 'WM')      Waste Management Inc.
# 39       7                 ('3M Company', 'MMM')                 3M Company
# 40       7                  ('McDonalds', 'MCD')                  McDonalds
# 41       7          ('Johnson & Johnson', 'JNJ')          Johnson & Johnson
# 42       7       ('JPMorgan Chase & Co.', 'JPM')       JPMorgan Chase & Co.
# 43       8                 ('Microsoft', 'MSFT')                  Microsoft
# 44       8  ('Pioneer Natural Resources', 'PXD')  Pioneer Natural Resources
# 45       8          ('Texas Instruments', 'TXN')          Texas Instruments
# 46       8    ('UnitedHealth Group Inc.', 'UNH')    UnitedHealth Group Inc.
# 47       8                ('Adobe Inc.', 'ADBE')                 Adobe Inc.
# 48       8           ('Vulcan Materials', 'VMC')           Vulcan Materials
# 49       9      ('United Parcel Service', 'UPS')      United Parcel Service
#
#    company_symbol
# 0             LNC
# 1            AMAT
# 2             NEE
# 3            AMZN
# 4             AXP
# 5             TGT
# 6             NUE
# 7             LEN
# 8              KR
# 9             MAS
# 10            IBM
# 11           NFLX
# 12          GOOGL
# 13            LLY
# 14           AMGN
# 15              V
# 16             VZ
# 17            NOC
# 18             DE
# 19             BA
# 20             MA
# 21             GE
# 22            WHR
# 23           AAPL
# 24            ABC
# 25            LMT
# 26            HCA
# 27             GM
# 28            PGR
# 29            WBA
# 30            TJX
# 31            PLD
# 32            CVX
# 33             CE
# 34           INTC
# 35             KO
# 36            MDT
# 37            PEP
# 38             WM
# 39            MMM
# 40            MCD
# 41            JNJ
# 42            JPM
# 43           MSFT
# 44            PXD
# 45            TXN
# 46            UNH
# 47           ADBE
# 48            VMC
# 49            UPS

# %%
sorted_df[['company_name', 'company_symbol']]=sorted_df['companies'].str.replace('(', '').str.replace(')', '').str.replace("'", '').str.split(', ', expand=True)#[1]
# sorted_df
sorted_df=sorted_df.replace({'Alphabet Inc. Class A': 'Alphabet Inc. (Class A)', 
                   'Lilly Eli & Co.': 'Lilly (Eli) & Co.'})
sorted_df
# Out:
#     labels                             companies               company_name  \
# 0        0           ('Lincoln National', 'LNC')           Lincoln National
# 1        0    ('Applied Materials Inc.', 'AMAT')     Applied Materials Inc.
# 2        0             ('NextEra Energy', 'NEE')             NextEra Energy
# 3        0                    ('Amazon', 'AMZN')                     Amazon
# 4        0           ('American Express', 'AXP')           American Express
# 5        0               ('Target Corp.', 'TGT')               Target Corp.
# 6        0                ('Nucor Corp.', 'NUE')                Nucor Corp.
# 7        0               ('Lennar Corp.', 'LEN')               Lennar Corp.
# 8        1                  ('Kroger Co.', 'KR')                 Kroger Co.
# 9        1                ('Masco Corp.', 'MAS')                Masco Corp.
# 10       1                        ('IBM', 'IBM')                        IBM
# 11       1              ('Netflix Inc.', 'NFLX')               Netflix Inc.
# 12       1  ('Alphabet Inc. (Class A)', 'GOOGL')    Alphabet Inc. (Class A)
# 13       1          ('Lilly (Eli) & Co.', 'LLY')          Lilly (Eli) & Co.
# 14       1                ('Amgen Inc.', 'AMGN')                 Amgen Inc.
# 15       1                    ('Visa Inc.', 'V')                  Visa Inc.
# 16       1      ('Verizon Communications', 'VZ')     Verizon Communications
# 17       1           ('Northrop Grumman', 'NOC')           Northrop Grumman
# 18       2                 ('Deere & Co.', 'DE')                Deere & Co.
# 19       2                      ('Boeing', 'BA')                     Boeing
# 20       2                  ('MasterCard', 'MA')                 MasterCard
# 21       2            ('General Electric', 'GE')           General Electric
# 22       3            ('Whirlpool Corp.', 'WHR')            Whirlpool Corp.
# 23       3                     ('Apple', 'AAPL')                      Apple
# 24       3          ('AmerisourceBergen', 'ABC')          AmerisourceBergen
# 25       3            ('Lockheed Martin', 'LMT')            Lockheed Martin
# 26       3             ('HCA Healthcare', 'HCA')             HCA Healthcare
# 27       3              ('General Motors', 'GM')             General Motors
# 28       4          ('Progressive Corp.', 'PGR')          Progressive Corp.
# 29       4                   ('Walgreen', 'WBA')                   Walgreen
# 30       4         ('TJX Companies Inc.', 'TJX')         TJX Companies Inc.
# 31       4                   ('Prologis', 'PLD')                   Prologis
# 32       4              ('Chevron Corp.', 'CVX')              Chevron Corp.
# 33       5                    ('Celanese', 'CE')                   Celanese
# 34       5                     ('Intel', 'INTC')                      Intel
# 35       6                   ('Coca Cola', 'KO')                  Coca Cola
# 36       6              ('Medtronic plc', 'MDT')              Medtronic plc
# 37       6                      ('Pepsi', 'PEP')                      Pepsi
# 38       6       ('Waste Management Inc.', 'WM')      Waste Management Inc.
# 39       7                 ('3M Company', 'MMM')                 3M Company
# 40       7                  ('McDonalds', 'MCD')                  McDonalds
# 41       7          ('Johnson & Johnson', 'JNJ')          Johnson & Johnson
# 42       7       ('JPMorgan Chase & Co.', 'JPM')       JPMorgan Chase & Co.
# 43       8                 ('Microsoft', 'MSFT')                  Microsoft
# 44       8  ('Pioneer Natural Resources', 'PXD')  Pioneer Natural Resources
# 45       8          ('Texas Instruments', 'TXN')          Texas Instruments
# 46       8    ('UnitedHealth Group Inc.', 'UNH')    UnitedHealth Group Inc.
# 47       8                ('Adobe Inc.', 'ADBE')                 Adobe Inc.
# 48       8           ('Vulcan Materials', 'VMC')           Vulcan Materials
# 49       9      ('United Parcel Service', 'UPS')      United Parcel Service
#
#    company_symbol
# 0             LNC
# 1            AMAT
# 2             NEE
# 3            AMZN
# 4             AXP
# 5             TGT
# 6             NUE
# 7             LEN
# 8              KR
# 9             MAS
# 10            IBM
# 11           NFLX
# 12          GOOGL
# 13            LLY
# 14           AMGN
# 15              V
# 16             VZ
# 17            NOC
# 18             DE
# 19             BA
# 20             MA
# 21             GE
# 22            WHR
# 23           AAPL
# 24            ABC
# 25            LMT
# 26            HCA
# 27             GM
# 28            PGR
# 29            WBA
# 30            TJX
# 31            PLD
# 32            CVX
# 33             CE
# 34           INTC
# 35             KO
# 36            MDT
# 37            PEP
# 38             WM
# 39            MMM
# 40            MCD
# 41            JNJ
# 42            JPM
# 43           MSFT
# 44            PXD
# 45            TXN
# 46            UNH
# 47           ADBE
# 48            VMC
# 49            UPS

# %%
test=pd.to_datetime(['2021-04-16 00:00:00+00:00'])
# test.strftime('%Y-%m-%d')
test.tz_convert(None)
# Out:
# DatetimeIndex(['2021-04-16'], dtype='datetime64[ns]', freq=None)

# %%
movement_df=pd.read_csv('output/movements_df.csv')
# movement_df
# columns=movement_df.iloc[0, :]
# columns

# movement_df=movement_df.iloc[1:]
# columns=movement_df.iloc[:, 0]
# movement_df=movement_df.transpose()
# movement_df.columns=columns
# movement_df=movement_df.iloc[1:]
columns=list(movement_df.columns)
new_columns=[]
for each_column in columns: 
#     print(each_column)
    new_columns.append(each_column.replace('00:00:00+00:00', ''))
movement_df.columns=new_columns
# movement_df.head()

# %%
combined_df['labels'].value_counts()
# Out:
# 4    8
# 2    6
# 1    6
# 0    6
# 7    5
# 3    5
# 9    4
# 8    4
# 6    4
# 5    2
# Name: labels, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
combined_df=pd.merge(movement_df, sorted_df, left_on='Unnamed: 0', right_on='company_name', how='outer')
combined_df=combined_df.drop(columns=['companies', 'company_name', 'company_symbol'])
combined_df
for each_cluster in range(0, 10): 
    graph_df=combined_df[combined_df['labels']==each_cluster].drop(columns=['labels'])
    graph_df=graph_df.transpose()#.plot()
    columns=graph_df.iloc[0]
    graph_df.columns=columns
    graph_df.iloc[1:].plot(rot=90, legend=False)
    plt.legend(bbox_to_anchor=(1, 1))
    plt.savefig(f'static/charts/cluster_{each_cluster}')

# %%
test_df=graph_df.transpose()
test_df.plot()
